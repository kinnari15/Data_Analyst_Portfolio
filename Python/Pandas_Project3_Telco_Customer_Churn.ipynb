# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\kinnari\Desktop\Data_Analysis\Python\Telco_Customer_Churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
#Droping the duplicates if any

df = df.drop_duplicates()
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# It is observed that there were no duplicates in the dataset which is the first milestone in data cleaning.

# %%
df1 = df.drop(columns=['SeniorCitizen','Partner'])

# %%
#columns_replaced = ["Dependents","PhoneService","MultipleLines","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies","PaperlessBilling","Churn"]

#df[columns_replaced] = df[columns_replaced].str.replace('Yes', 'Y')
#df[columns_replaced] = df[columns_replaced].str.replace('No','N')

df2 = df1.replace(['Yes', 'No'], ['Y', 'N'])

# %%
df2
# Out:
#       customerID  gender Dependents  tenure PhoneService     MultipleLines  \
# 0     7590-VHVEG  Female          N       1            N  No phone service
# 1     5575-GNVDE    Male          N      34            Y                 N
# 2     3668-QPYBK    Male          N       2            Y                 N
# 3     7795-CFOCW    Male          N      45            N  No phone service
# 4     9237-HQITU  Female          N       2            Y                 N
# ...          ...     ...        ...     ...          ...               ...
# 7038  6840-RESVB    Male          Y      24            Y                 Y
# 7039  2234-XADUH  Female          Y      72            Y                 Y
# 7040  4801-JZAZL  Female          Y      11            N  No phone service
# 7041  8361-LTMKD    Male          N       4            Y                 Y
# 7042  3186-AJIEK    Male          N      66            Y                 N
#
# ...

# %%
df2.groupby('PaymentMethod').mean(numeric_only=True)
# Out:
#                               tenure  MonthlyCharges
# PaymentMethod
# Bank transfer (automatic)  43.656736       67.192649
# Credit card (automatic)    43.269382       66.512385
# Electronic check           25.174630       76.255814
# Mailed check               21.830025       43.917060

# %%
df2[df2['gender'].str.contains('Female')]
# Out:
#       customerID  gender Dependents  tenure PhoneService     MultipleLines  \
# 0     7590-VHVEG  Female          N       1            N  No phone service
# 4     9237-HQITU  Female          N       2            Y                 N
# 5     9305-CDSKC  Female          N       8            Y                 Y
# 7     6713-OKOMC  Female          N      10            N  No phone service
# 8     7892-POOKP  Female          N      28            Y                 Y
# ...          ...     ...        ...     ...          ...               ...
# 7034  0639-TSIQW  Female          N      67            Y                 Y
# 7036  7750-EYXWZ  Female          N      12            N  No phone service
# 7037  2569-WGERO  Female          N      72            Y                 N
# 7039  2234-XADUH  Female          Y      72            Y                 Y
# 7040  4801-JZAZL  Female          Y      11            N  No phone service
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# ...

# %%
df2[df2['gender'].str.contains('Male')]
# Out:
#       customerID gender Dependents  tenure PhoneService     MultipleLines  \
# 1     5575-GNVDE   Male          N      34            Y                 N
# 2     3668-QPYBK   Male          N       2            Y                 N
# 3     7795-CFOCW   Male          N      45            N  No phone service
# 6     1452-KIOVK   Male          Y      22            Y                 Y
# 9     6388-TABGU   Male          Y      62            Y                 N
# ...          ...    ...        ...     ...          ...               ...
# 7033  9767-FFLEM   Male          N      38            Y                 N
# 7035  8456-QDAVC   Male          N      19            Y                 N
# 7038  6840-RESVB   Male          Y      24            Y                 Y
# 7041  8361-LTMKD   Male          N       4            Y                 Y
# 7042  3186-AJIEK   Male          N      66            Y                 N
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# ...

# %%
df2.sort_values(by='tenure').head(20)
# Out:
#       customerID  gender Dependents  tenure PhoneService     MultipleLines  \
# 1340  1371-DWPAZ  Female          Y       0            N  No phone service
# 936   5709-LVOEQ  Female          Y       0            Y                 N
# 6670  4075-WKNIU  Female          Y       0            Y                 Y
# 4380  2520-SGTTA  Female          Y       0            Y                 N
# 5218  2923-ARZLG    Male          Y       0            Y                 N
# 3826  3213-VVOLG    Male          Y       0            Y                 Y
# 753   3115-CZMZD    Male          Y       0            Y                 N
# 6754  2775-SEFEE    Male          Y       0            Y                 Y
# 3331  7644-OMVMY    Male          Y       0            Y                 N
# 488   4472-LVYGI  Female          Y       0            N  No phone service
# 1082  4367-NUYAO    Male          Y       0            Y                 Y
# ...

# %%
df2.dtypes
# Out:
# customerID           object
# gender               object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df2.select_dtypes(include='object')
# Out:
#       customerID  gender Dependents PhoneService     MultipleLines  \
# 0     7590-VHVEG  Female          N            N  No phone service
# 1     5575-GNVDE    Male          N            Y                 N
# 2     3668-QPYBK    Male          N            Y                 N
# 3     7795-CFOCW    Male          N            N  No phone service
# 4     9237-HQITU  Female          N            Y                 N
# ...          ...     ...        ...          ...               ...
# 7038  6840-RESVB    Male          Y            Y                 Y
# 7039  2234-XADUH  Female          Y            Y                 Y
# 7040  4801-JZAZL  Female          Y            N  No phone service
# 7041  8361-LTMKD    Male          N            Y                 Y
# 7042  3186-AJIEK    Male          N            Y                 N
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL              N            Y                N           N
# ...

# %%
#changing object to float - "TotalCharges"

df2['TotalCharges'] = pd.to_numeric(df2['TotalCharges'], errors='coerce')

# %%
df2.dtypes
# Out:
# customerID           object
# gender               object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df2.describe()
# Out:
#        tenure  MonthlyCharges  TotalCharges
# count 7043.00         7043.00       7032.00
# mean    32.37           64.76       2283.30
# std     24.56           30.09       2266.77
# min      0.00           18.25         18.80
# 25%      9.00           35.50        401.45
# 50%     29.00           70.35       1397.47
# 75%     55.00           89.85       3794.74
# max     72.00          118.75       8684.80
